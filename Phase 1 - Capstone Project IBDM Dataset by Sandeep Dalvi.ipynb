# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def fetch_imdb_data(url):
    # Sending a request to the IMDb URL and get the response
    response = requests.get(url)
    
    # Parseing the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Finding all movie containers on the page
    movie_containers = soup.find_all('div', class_='lister-item mode-advanced')
    
    # Lists to store data for CSV files
    csv1_data = []
    csv2_data = []

    # Loop through the first 100 movie containers
    for index, movie in enumerate(movie_containers[:100], start=1):
        # Extract movie details
        # Serial Number (sno)
        sno = index

        # Movie Name
        movie_name = movie.h3.a.text

        # Duration and Year
        duration_year = movie.find('span', class_='runtime').text
        duration = int(duration_year.split()[0])
        year = int(movie.find('span', class_='lister-item-year').text.strip('()'))

        # Ratings and Metascore
        ratings = float(movie.strong.text)
        metascore = int(movie.find('span', class_='metascore').text.strip()) if movie.find('span', class_='metascore') else None

        # Director and Stars
        credits = movie.find('p', class_='').text.strip().split('|')
        director = credits[0].strip().replace('Director:', '')
        stars = credits[1].strip().replace('Stars:', '')

        # Votes, Genre, Gross Collection, Popularity, and Certification
        votes = int(movie.find('span', attrs={'name': 'nv'})['data-value'].replace(',', ''))
        genre = movie.find('span', class_='genre').text.strip()
        gross = movie.find('p', class_='sort-num_votes-visible').find_all('span')[-1]['data-value']
        popularity_elem = movie.find('span', class_='global-sprite')
        popularity = float(popularity_elem.text) if (popularity_elem and popularity_elem.text.strip()) else None
        certification = movie.find('span', class_='certificate').text.strip() if movie.find('span', class_='certificate') else None

        # Append data to respective lists
        csv1_data.append([sno, movie_name, director, duration, year, ratings, metascore])
        csv2_data.append([movie_name, stars, votes, genre, gross, popularity, certification])

    # Creating DataFrames for CSV files
    csv1_df = pd.DataFrame(csv1_data, columns=['sno', 'Movie Name', 'Director', 'Duration', 'Year', 'Ratings', 'Metascore'])
    csv2_df = pd.DataFrame(csv2_data, columns=['Movie Name', 'Stars', 'Votes', 'Genre', 'Gross Collection', 'Popularity', 'Certification'])

    # Separating Director1 and Director2
    csv1_df[['Director1', 'Director2']] = csv1_df['Director'].str.split(', ', 1, expand=True)

    # Separating Stars into Star1, Star2, Star3, and Star4
    star_split = csv2_df['Stars'].str.split(', ', expand=True)
    csv2_df['Star1'] = star_split[0]
    csv2_df['Star2'] = star_split[1]
    csv2_df['Star3'] = star_split[2]
    csv2_df['Star4'] = star_split[3]

    # Separating Genre1, Genre2, and Genre3
    genre_split = csv2_df['Genre'].str.split(', ', 2, expand=True)
    csv2_df['Genre1'] = genre_split[0]
    csv2_df['Genre2'] = genre_split[1]
    csv2_df['Genre3'] = genre_split[2]

    # Droping unnecessary columns
    csv1_df.drop(columns=['Director'], inplace=True)
    csv2_df.drop(columns=['Stars', 'Genre'], inplace=True)

    return csv1_df, csv2_df

def save_to_csv(df, file_name):
    df.to_csv(file_name, index=False)

if __name__ == "__main__":
    # Fetching data from IMDb website
    url = 'https://www.imdb.com/search/title/?genres=action&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=XZ8X52H1R40B7KG5SNZ9&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_1'
    csv1_df, csv2_df = fetch_imdb_data(url)

    # Saving the DataFrames to CSV files
    save_to_csv(csv1_df, 'IMDbMoviesInfo.csv')
    save_to_csv(csv2_df, 'IMDbMoviesDetails.csv')

    # Printing a message to confirm the CSV files are created
    print("CSV files 'IMDbMoviesInfo.csv' and 'IMDbMoviesDetails.csv' have been created.")

    # Read the data from the new CSV files
    csv1_df = pd.read_csv('IMDbMoviesInfo.csv')
    csv2_df = pd.read_csv('IMDbMoviesDetails.csv')
# Out:
# CSV files 'IMDbMoviesInfo.csv' and 'IMDbMoviesDetails.csv' have been created.

# %%
# Print DataFrames (if needed)
print("\nContents of IMDbMoviesInfo.csv:")
print(csv1_df)
print("\nContents of IMDbMoviesDetails.csv:")
print(csv2_df)
# Out:
# Contents of IMDbMoviesInfo.csv:
#     sno                                         Movie Name  Duration  Year  \
# 0     1                                    The Dark Knight       152  2008
# 1     2      The Lord of the Rings: The Return of the King       201  2003
# 2     3                Spider-Man: Across the Spider-Verse       140  2023
# 3     4                                          Inception       148  2010
# 4     5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# 5     6              The Lord of the Rings: The Two Towers       179  2002
# 6     7                                         The Matrix       136  1999
# 7     8     Star Wars: Episode V - The Empire Strikes Back       124  1980
# 8     9                                    Soorarai Pottru       153  2020
# 9    10                         Terminator 2: Judgment Day       137  1991
# 10   11                                          Star Wars       121  1977
# 11   12                               Shichinin no samurai       207  1954
# 12   13                                            Seppuku       133  1962
# 13   14                                         Sita Ramam       163  2022
# 14   15                                          Gladiator       155  2000
# 15   16                                               Léon       110  1994
# 16   17                            Raiders of the Lost Ark       115  1981
# 17   18                  Spider-Man: Into the Spider-Verse       117  2018
# 18   19                              The Dark Knight Rises       164  2012
# 19   20                                  Avengers: Endgame       181  2019
# 20   21                                             Aliens       137  1986
# 21   22                                           Oldeuboi       101  2003
# 22   23                             Avengers: Infinity War       149  2018
# 23   24                                             Kaithi       145  2019
# 24   25                                             Asuran       141  2019
# 25   26                                  Top Gun: Maverick       130  2022
# 26   27                                               Heat       170  1995
# 27   28         Star Wars: Episode VI - Return of the Jedi       131  1983
# 28   29                                      Mononoke-hime       134  1997
# 29   30                                 North by Northwest       136  1959
# 30   31                                             Dangal       161  2016
# 31   32                                            Kantara       148  2022
# 32   33                                   K.G.F: Chapter 2       168  2022
# 33   34                                             Vikram       175  2022
# 34   35                                          Shershaah       135  2021
# 35   36                                           Ratsasan       170  2018
# 36   37                 Indiana Jones and the Last Crusade       127  1989
# 37   38                                      Jurassic Park       127  1993
# 38   39                                      Batman Begins       140  2005
# 39   40                            Spider-Man: No Way Home       148  2021
# 40   41                                               1917       119  2019
# 41   42                                           Die Hard       132  1988
# 42   43                                  Kill Bill: Vol. 1       111  2003
# 43   44                                     V for Vendetta       132  2005
# 44   45                                                Ran       162  1985
# 45   46                 Kimetsu no Yaiba: Mugen Ressha-Hen       117  2020
# 46   47                        Baahubali 2: The Conclusion       167  2017
# 47   48                                 Gangs of Wasseypur       321  2012
# 48   49                                            Yôjinbô       110  1961
# 49   50                           Uri: The Surgical Strike       138  2019
#
#     Ratings  Metascore                       Director1  \
# 0       9.0       84.0             \nChristopher Nolan
# 1       9.0       94.0                 \nPeter Jackson
# 2       8.9       86.0  Directors:\nJoaquim Dos Santos
# 3       8.8       74.0             \nChristopher Nolan
# 4       8.8       92.0                 \nPeter Jackson
# 5       8.8       87.0                 \nPeter Jackson
# 6       8.7       73.0      Directors:\nLana Wachowski
# 7       8.7       82.0                \nIrvin Kershner
# 8       8.7        NaN                 \nSudha Kongara
# 9       8.6       75.0                 \nJames Cameron
# 10      8.6       90.0                  \nGeorge Lucas
# 11      8.6       98.0                \nAkira Kurosawa
# 12      8.6       85.0              \nMasaki Kobayashi
# 13      8.6        NaN              \nHanu Raghavapudi
# 14      8.5       67.0                  \nRidley Scott
# 15      8.5       64.0                    \nLuc Besson
# 16      8.4       85.0              \nSteven Spielberg
# 17      8.4       87.0     Directors:\nBob Persichetti
# 18      8.4       78.0             \nChristopher Nolan
# 19      8.4       78.0       Directors:\nAnthony Russo
# 20      8.4       84.0                 \nJames Cameron
# 21      8.4       77.0                \nPark Chan-wook
# 22      8.4       68.0       Directors:\nAnthony Russo
# 23      8.4        NaN              \nLokesh Kanagaraj
# 24      8.4        NaN                   \nVetrimaaran
# 25      8.3       78.0               \nJoseph Kosinski
# 26      8.3       76.0                  \nMichael Mann
# 27      8.3       58.0              \nRichard Marquand
# 28      8.3       76.0                \nHayao Miyazaki
# 29      8.3       98.0              \nAlfred Hitchcock
# 30      8.3        NaN                 \nNitesh Tiwari
# 31      8.3        NaN                 \nRishab Shetty
# 32      8.3        NaN                \nPrashanth Neel
# 33      8.3        NaN              \nLokesh Kanagaraj
# 34      8.3        NaN                 \nVishnuvardhan
# 35      8.3        NaN                     \nRam Kumar
# 36      8.2       65.0              \nSteven Spielberg
# 37      8.2       68.0              \nSteven Spielberg
# 38      8.2       70.0             \nChristopher Nolan
# 39      8.2       71.0                     \nJon Watts
# 40      8.2       78.0                    \nSam Mendes
# 41      8.2       72.0                \nJohn McTiernan
# 42      8.2       69.0             \nQuentin Tarantino
# 43      8.2       62.0                \nJames McTeigue
# 44      8.2       97.0                \nAkira Kurosawa
# 45      8.2       72.0                \nHaruo Sotozaki
# 46      8.2        NaN                \nS.S. Rajamouli
# 47      8.2       89.0                \nAnurag Kashyap
# 48      8.2       93.0                \nAkira Kurosawa
# 49      8.2        NaN                   \nAditya Dhar
#
#                               Director2
# 0                                   NaN
# 1                                   NaN
# 2   \nKemp Powers, \nJustin K. Thompson
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                     \nLilly Wachowski
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17     \nPeter Ramsey, \nRodney Rothman
# 18                                  NaN
# 19                          \nJoe Russo
# 20                                  NaN
# 21                                  NaN
# 22                          \nJoe Russo
# 23                                  NaN
# 24                                  NaN
# 25                                  NaN
# 26                                  NaN
# 27                                  NaN
# 28                                  NaN
# 29                                  NaN
# 30                                  NaN
# 31                                  NaN
# 32                                  NaN
# 33                                  NaN
# 34                                  NaN
# 35                                  NaN
# 36                                  NaN
# 37                                  NaN
# 38                                  NaN
# 39                                  NaN
# 40                                  NaN
# 41                                  NaN
# 42                                  NaN
# 43                                  NaN
# 44                                  NaN
# 45                                  NaN
# 46                                  NaN
# 47                                  NaN
# 48                                  NaN
# 49                                  NaN
#
# Contents of IMDbMoviesDetails.csv:
#                                            Movie Name    Votes  \
# 0                                     The Dark Knight  2746898
# 1       The Lord of the Rings: The Return of the King  1901241
# 2                 Spider-Man: Across the Spider-Verse   191438
# 3                                           Inception  2437787
# 4   The Lord of the Rings: The Fellowship of the Ring  1929591
# 5               The Lord of the Rings: The Two Towers  1715719
# 6                                          The Matrix  1973481
# 7      Star Wars: Episode V - The Empire Strikes Back  1331313
# 8                                     Soorarai Pottru   120110
# 9                          Terminator 2: Judgment Day  1132377
# 10                                          Star Wars  1403503
# 11                               Shichinin no samurai   355314
# 12                                            Seppuku    62337
# 13                                         Sita Ramam    61561
# 14                                          Gladiator  1548002
# 15                                               Léon  1198846
# 16                            Raiders of the Lost Ark  1005023
# 17                  Spider-Man: Into the Spider-Verse   611920
# 18                              The Dark Knight Rises  1757420
# 19                                  Avengers: Endgame  1197274
# 20                                             Aliens   737743
# 21                                           Oldeuboi   602343
# 22                             Avengers: Infinity War  1139385
# 23                                             Kaithi    36857
# 24                                             Asuran    31567
# 25                                  Top Gun: Maverick   612778
# 26                                               Heat   684205
# 27         Star Wars: Episode VI - Return of the Jedi  1085357
# 28                                      Mononoke-hime   410961
# 29                                 North by Northwest   336675
# 30                                             Dangal   199361
# 31                                            Kantara    96994
# 32                                   K.G.F: Chapter 2   141171
# 33                                             Vikram    64888
# 34                                          Shershaah   125646
# 35                                           Ratsasan    47541
# 36                 Indiana Jones and the Last Crusade   785231
# 37                                      Jurassic Park  1024335
# 38                                      Batman Begins  1517368
# 39                            Spider-Man: No Way Home   815853
# 40                                               1917   631012
# 41                                           Die Hard   906945
# 42                                  Kill Bill: Vol. 1  1148879
# 43                                     V for Vendetta  1146896
# 44                                                Ran   130495
# 45                 Kimetsu no Yaiba: Mugen Ressha-Hen    66279
# 46                        Baahubali 2: The Conclusion   108203
# 47                                 Gangs of Wasseypur    99958
# 48                                            Yôjinbô   126865
# 49                           Uri: The Surgical Strike    68404
#
#    Gross Collection  Popularity Certification                    Star1  \
# 0       534,858,444         NaN            UA         \nChristian Bale
# 1       377,845,905         NaN             U            \nElijah Wood
# 2            191438         NaN             U          \nShameik Moore
# 3       292,576,195         NaN            UA      \nLeonardo DiCaprio
# 4       315,544,750         NaN             U            \nElijah Wood
# 5       342,551,365         NaN            UA            \nElijah Wood
# 6       171,479,930         NaN             A           \nKeanu Reeves
# 7       290,475,067         NaN            UA            \nMark Hamill
# 8            120110         NaN             U                 \nSuriya
# 9       204,843,350         NaN             A  \nArnold Schwarzenegger
# 10      322,740,140         NaN             U            \nMark Hamill
# 11          269,061         NaN             U         \nToshirô Mifune
# 12            62337         NaN           NaN        \nTatsuya Nakadai
# 13            61561         NaN             U        \nDulquer Salmaan
# 14      187,705,427         NaN            UA          \nRussell Crowe
# 15       19,501,238         NaN             A              \nJean Reno
# 16      248,159,971         NaN             A          \nHarrison Ford
# 17      190,241,310         NaN             U          \nShameik Moore
# 18      448,139,099         NaN            UA         \nChristian Bale
# 19      858,373,000         NaN            UA      \nRobert Downey Jr.
# 20       85,160,248         NaN             U       \nSigourney Weaver
# 21          707,481         NaN             A           \nChoi Min-sik
# 22      678,815,482         NaN            UA      \nRobert Downey Jr.
# 23            36857         NaN            UA                 \nKarthi
# 24            31567         NaN            UA                \nDhanush
# 25      718,732,821         NaN            UA             \nTom Cruise
# 26       67,436,818         NaN             A              \nAl Pacino
# 27      309,125,409         NaN             U            \nMark Hamill
# 28        2,375,308         NaN             U           \nYôji Matsuda
# 29       13,275,000         NaN             U             \nCary Grant
# 30       12,391,761         NaN             U             \nAamir Khan
# 31            96994         NaN            UA          \nRishab Shetty
# 32        6,604,562         NaN            UA                   \nYash
# 33            64888         NaN            UA           \nKamal Haasan
# 34           125646         NaN            UA      \nSidharth Malhotra
# 35            47541         NaN            UA          \nVishnu Vishal
# 36      197,171,806         NaN             U          \nHarrison Ford
# 37      402,453,882         NaN            UA              \nSam Neill
# 38      206,852,432         NaN            UA         \nChristian Bale
# 39      804,747,988         NaN            UA            \nTom Holland
# 40      159,227,644         NaN             R   \nDean-Charles Chapman
# 41       83,008,852         NaN             A           \nBruce Willis
# 42       70,099,045         NaN             A            \nUma Thurman
# 43       70,511,035         NaN            UA           \nHugo Weaving
# 44        4,135,750         NaN     Not Rated        \nTatsuya Nakadai
# 45       47,700,000         NaN            UA          \nNatsuki Hanae
# 46       20,186,659         NaN            UA                \nPrabhas
# 47            99958         NaN             A         \nManoj Bajpayee
# 48           126865         NaN             U         \nToshirô Mifune
# 49        4,186,168         NaN            UA          \nVicky Kaushal
#
#                      Star2                   Star3                   Star4  \
# 0           \nHeath Ledger         \nAaron Eckhart         \nMichael Caine
# 1        \nViggo Mortensen          \nIan McKellen         \nOrlando Bloom
# 2       \nHailee Steinfeld     \nBrian Tyree Henry     \nLuna Lauren Velez
# 3   \nJoseph Gordon-Levitt           \nElliot Page          \nKen Watanabe
# 4           \nIan McKellen         \nOrlando Bloom             \nSean Bean
# 5           \nIan McKellen       \nViggo Mortensen         \nOrlando Bloom
# 6     \nLaurence Fishburne      \nCarrie-Anne Moss          \nHugo Weaving
# 7          \nHarrison Ford         \nCarrie Fisher    \nBilly Dee Williams
# 8           \nParesh Rawal     \nAparna Balamurali        \nVivek Prasanna
# 9         \nLinda Hamilton        \nEdward Furlong        \nRobert Patrick
# 10         \nHarrison Ford         \nCarrie Fisher         \nAlec Guinness
# 11       \nTakashi Shimura        \nKeiko Tsushima      \nYukiko Shimazaki
# 12        \nAkira Ishihama        \nShima Iwashita         \nTetsurô Tanba
# 13         \nMrunal Thakur     \nRashmika Mandanna               \nSumanth
# 14       \nJoaquin Phoenix        \nConnie Nielsen           \nOliver Reed
# 15           \nGary Oldman       \nNatalie Portman          \nDanny Aiello
# 16           \nKaren Allen          \nPaul Freeman      \nJohn Rhys-Davies
# 17          \nJake Johnson      \nHailee Steinfeld        \nMahershala Ali
# 18             \nTom Hardy         \nAnne Hathaway           \nGary Oldman
# 19           \nChris Evans          \nMark Ruffalo       \nChris Hemsworth
# 20         \nMichael Biehn           \nCarrie Henn           \nPaul Reiser
# 21            \nYoo Ji-tae        \nKang Hye-jeong         \nKim Byeong-Ok
# 22       \nChris Hemsworth          \nMark Ruffalo           \nChris Evans
# 23                \nNarain             \nArjun Das         \nGeorge Maryan
# 24         \nManju Warrier           \nPrakash Raj             \nPasupathy
# 25     \nJennifer Connelly          \nMiles Teller            \nVal Kilmer
# 26        \nRobert De Niro            \nVal Kilmer            \nJon Voight
# 27         \nHarrison Ford         \nCarrie Fisher    \nBilly Dee Williams
# 28         \nYuriko Ishida           \nYûko Tanaka          \nBilly Crudup
# 29       \nEva Marie Saint           \nJames Mason   \nJessie Royce Landis
# 30         \nSakshi Tanwar    \nFatima Sana Shaikh        \nSanya Malhotra
# 31      \nKishore Kumar G.         \nAchyuth Kumar        \nSapthami Gowda
# 32           \nSanjay Dutt        \nRaveena Tandon       \nSrinidhi Shetty
# 33      \nVijay Sethupathi         \nFahadh Faasil                \nNarain
# 34          \nKiara Advani          \nShiv Panditt       \nPranay Pachauri
# 35            \nAmala Paul            \nRadha Ravi       \nSangili Murugan
# 36          \nSean Connery          \nAlison Doody       \nDenholm Elliott
# 37            \nLaura Dern         \nJeff Goldblum  \nRichard Attenborough
# 38         \nMichael Caine          \nKen Watanabe           \nLiam Neeson
# 39               \nZendaya  \nBenedict Cumberbatch         \nJacob Batalon
# 40         \nGeorge MacKay           \nDaniel Mays           \nColin Firth
# 41          \nAlan Rickman        \nBonnie Bedelia   \nReginald VelJohnson
# 42       \nDavid Carradine          \nDaryl Hannah        \nMichael Madsen
# 43       \nNatalie Portman         \nRupert Graves           \nStephen Rea
# 44           \nAkira Terao         \nJinpachi Nezu           \nDaisuke Ryû
# 45            \nAkari Kitô   \nYoshitsugu Matsuoka          \nHiro Shimono
# 46        \nRana Daggubati        \nAnushka Shetty      \nTamannaah Bhatia
# 47   \nNawazuddin Siddiqui      \nTigmanshu Dhulia          \nRicha Chadha
# 48           \nEijirô Tôno       \nTatsuya Nakadai          \nYôko Tsukasa
# 49          \nParesh Rawal           \nMohit Raina           \nYami Gautam
#
#        Genre1     Genre2     Genre3
# 0      Action      Crime      Drama
# 1      Action  Adventure      Drama
# 2   Animation     Action  Adventure
# 3      Action  Adventure     Sci-Fi
# 4      Action  Adventure      Drama
# 5      Action  Adventure      Drama
# 6      Action     Sci-Fi        NaN
# 7      Action  Adventure    Fantasy
# 8      Action      Drama        NaN
# 9      Action     Sci-Fi        NaN
# 10     Action  Adventure    Fantasy
# 11     Action      Drama        NaN
# 12     Action      Drama    Mystery
# 13     Action      Drama    Mystery
# 14     Action  Adventure      Drama
# 15     Action      Crime      Drama
# 16     Action  Adventure        NaN
# 17  Animation     Action  Adventure
# 18     Action      Drama   Thriller
# 19     Action  Adventure      Drama
# 20     Action  Adventure     Sci-Fi
# 21     Action      Drama    Mystery
# 22     Action  Adventure     Sci-Fi
# 23     Action  Adventure      Crime
# 24     Action      Drama        NaN
# 25     Action      Drama        NaN
# 26     Action      Crime      Drama
# 27     Action  Adventure    Fantasy
# 28  Animation     Action  Adventure
# 29     Action  Adventure    Mystery
# 30     Action  Biography      Drama
# 31     Action  Adventure      Drama
# 32     Action      Crime      Drama
# 33     Action      Crime   Thriller
# 34     Action  Biography      Drama
# 35     Action      Crime      Drama
# 36     Action  Adventure        NaN
# 37     Action  Adventure     Sci-Fi
# 38     Action      Crime      Drama
# 39     Action  Adventure    Fantasy
# 40     Action      Drama        War
# 41     Action   Thriller        NaN
# 42     Action      Crime   Thriller
# 43     Action      Drama     Sci-Fi
# 44     Action      Drama        War
# 45  Animation     Action  Adventure
# 46     Action      Drama        NaN
# 47     Action     Comedy      Crime
# 48     Action      Drama   Thriller
# 49     Action      Drama    History
